# %% [markdown]
# <a href="https://colab.research.google.com/github/scientist48/AI-Business-Intelligence-Analyst/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. My Lane and Why
#
# I selected the Content Refresh Prioritization lane.
#
# The goal is to identify pages that are likely to benefit from content updates and content refresh activities.
#
# Companies cannot update all pages at once, so machine learning can help prioritize pages that are most likely to benefit from updates.

# %% [markdown]
# # 2. The Question
#
# Decision:
# Which pages should be refreshed first?
#
# Action:
# The SEO team updates these pages.
#
# Cost of a wrong recommendation:
# If the model selects the wrong pages, time and resources are wasted.
# If important pages are missed, traffic and revenue opportunities may be lost.

# %% [markdown]
# # 3. Quick Look at the Data
#
# The dataset contains approximately 30,000 pages.
#
# More than half of the pages show declining trends.
#
# This suggests that prioritizing content refresh decisions could provide value to businesses.

# %%
total_pages = 30000
declining_rate = 0.542
hand_rule_p20 = 0.900

print("Total pages:", total_pages)
print("Declining rate:", declining_rate)
print("Hand Rule Precision@20:", hand_rule_p20)
# Out:
# Total pages: 30000
# Declining rate: 0.542
# Hand Rule Precision@20: 0.9

# %% [markdown]
# # 4. Careful Words
#
# This model cannot prove that refreshing content causes traffic growth.
#
# The model only identifies patterns associated with declining pages.
#
# Final decisions should always involve human review.

# %% [markdown]
# # 5. Self Check
#
# - Selected a lane ✔
# - Defined decision and action ✔
# - Included real numbers from the data ✔
# - Explained limitations ✔
